# %% [markdown]
# <a href="https://colab.research.google.com/github/iamafifaah/Google-Colab/blob/main/Geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install rasterio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 83.3 MB/s eta 0:00:00
# ...

# %%
pip install geopandas

# %%
from osgeo import gdal
import os
import glob
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show
import rasterio.mask
import numpy as np
import geopandas as gpd

# %%
shp = r'/content/data/Kecamatan.shp'

# %%
gdf = gpd.read_file(shp)

# %%
gdf.head()
# Out:
#   GID_0     NAME_0    GID_1        NAME_1 NL_NAME_1      GID_2         NAME_2  \
# 0   IDN  Indonesia  IDN.7_1  Jakarta Raya      None  IDN.7.1_1  Jakarta Barat
# 1   IDN  Indonesia  IDN.7_1  Jakarta Raya      None  IDN.7.1_1  Jakarta Barat
# 2   IDN  Indonesia  IDN.7_1  Jakarta Raya      None  IDN.7.1_1  Jakarta Barat
# 3   IDN  Indonesia  IDN.7_1  Jakarta Raya      None  IDN.7.1_1  Jakarta Barat
# 4   IDN  Indonesia  IDN.7_1  Jakarta Raya      None  IDN.7.1_1  Jakarta Barat
#
#   NL_NAME_2        GID_3            NAME_3 VARNAME_3 NL_NAME_3     TYPE_3  \
# 0      None  IDN.7.1.1_1        Cengkareng      None      None  Kecamatan
# 1      None  IDN.7.1.2_1  Grogolpetamburan      None      None  Kecamatan
# 2      None  IDN.7.1.3_1         Kalideres      None      None  Kecamatan
# 3      None  IDN.7.1.4_1        Kebonjeruk      None      None  Kecamatan
# 4      None  IDN.7.1.5_1         Kembangan      None      None  Kecamatan
#
#       ENGTYPE_3     CC_3 HASC_3  \
# ...

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.geom_type
# Out:
# 0          Polygon
# 1          Polygon
# 2          Polygon
# 3          Polygon
# 4          Polygon
# 5          Polygon
# 6          Polygon
# 7          Polygon
# 8          Polygon
# 9          Polygon
# 10         Polygon
# 11         Polygon
# 12         Polygon
# 13         Polygon
# 14         Polygon
# 15         Polygon
# 16         Polygon
# 17         Polygon
# 18         Polygon
# 19         Polygon
# 20    MultiPolygon
# 21         Polygon
# 22         Polygon
# 23         Polygon
# 24         Polygon
# 25         Polygon
# 26         Polygon
# 27         Polygon
# 28         Polygon
# 29         Polygon
# 30         Polygon
# 31         Polygon
# 32         Polygon
# 33         Polygon
# 34         Polygon
# 35         Polygon
# 36         Polygon
# 37         Polygon
# 38         Polygon
# 39    MultiPolygon
# 40         Polygon
# 41         Polygon
# 42         Polygon
# 43         Polygon
# 44    MultiPolygon
# dtype: object

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.plot('NAME_3')
# Out:
# <Axes: >

# %%
gdf.plot('NAME_2')
# Out:
# <Axes: >

# %%
gdf.plot('NAME_2', legend = True)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1,figsize=(6,8))
gdf.plot(ax=ax, column='NAME_2', legend=True, legend_kwds={"loc":'center left'})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04,0.5))

# %%
gdf.to_file(r'/content/data/Jakarta.shp')

# %% [markdown]
# --------------------------- END OF THE DAY-----------------------------------
